# %%
import numpy as np

# %%
x=np.array([50,70,100,120])
y=np.array([12,15,21,25])

# %%
# y= wx + b

# %%
sx = np.sum(x)
sy = np.sum(y)
sxy = np.sum(x*y)
sx2 = np.sum(x*x)

# %%
A = np.array([[len(x),sx],[sx,sx2]])
A1 = np.array([[len(x),sx],[sx,sx2]])
A2 = np.array([[sx,sy],[sx2,sxy]])
A3 = np
A
# Out:
# array([[    4,   340],
#        [  340, 31800]])

# %%
B= np.array([73,6750])
B
# Out:
# array([  73, 6750])

# %%
DA = np.linalg.det(A)
DA
# Out:
# 11599.999999999993

# %%
ans = np.linalg.solve(A,B)

# %%
import matplotlib.pyplot as plt

# %%
x_fit = np.linspace(min(x) - 10, max(x) + 10, 100)
y_fit = ans[0] + ans[1] * x_fit

# Plotting
plt.figure(figsize=(8, 6))
plt.scatter(x, y, color='red', label='Data Points')
plt.plot(x_fit, y_fit, color='blue', label=f'Fitted Line: y = {ans[0]:.2f} + {ans[1]:.2f}x')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Linear Curve Fitting using Cramer\'s Rule')
plt.legend()
plt.grid(True)
plt.show()

# %%
y
